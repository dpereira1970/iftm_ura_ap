# %%
First of all.

# %%
# %pip install -q ipywidgets

# %% [markdown]
# esta é uma célula de Markdown, e caso queira criar uma, siga dois passos simples:
# 1 - Crie uma nova célula,
# 2 - Selecione a célula(sem clicar dentro da área de digitar) e pressione M.
# Pronto, você agora tem uma célula de texto, ou Markdown.

# %%
#more code

# %% [markdown]
# É importante ressaltar que quando estiver editando a célula markdown, ela vai estar cinza até você clicar no play(run code).
